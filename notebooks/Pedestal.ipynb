# %%
import numpy as np
import matplotlib.pyplot as plt
import mplhep as hep

# %%
run_number = 2124
TMM = np.load(f'../Pedestal/TMM_ped_{run_number}.npz')
TMM_1st = np.load(f'../Pedestal/TMM_ped_1st{run_number}.npz')
ExMe = np.load(f'../Pedestal/ExMe_ped_{run_number}.npz')

# %%
# plt.hist(TMM['arr_0'][0]);
# plt.show()
# plt.hist(TMM['arr_2'][0]);
# plt.show()
# plt.hist(TMM['arr_3'][0], bins = 360);
# plt.show()

# %%
# plt.hist(ExMe['arr_0'][0]);
# plt.show()
# plt.hist(ExMe['arr_2'][0]);
# plt.show()
# plt.hist(ExMe['arr_3'][0], bins = 1024);
# plt.show()

# %%
import mplhep as hep
plt.style.use(hep.style.ATLAS)
plt.figure(figsize=(8,6), dpi = 100)
plt.bar(TMM['arr_3'][0], TMM['arr_0'][0], label = 'TMM', width = 0.5, align = 'center', alpha = 0.8)
plt.scatter(TMM['arr_3'][0],TMM['arr_0'][0], color = 'k', marker = '.', alpha = 0.5, s = 40)

plt.title('Pedestal')
plt.xlabel('Strip ID')
plt.ylabel('Entries')
plt.xlim(-10, 370)
# plt.ylim(-0.05,1)
plt.legend()
plt.tight_layout()
plt.savefig('../Pedestal/TMM_pedestal.pdf', dpi = 300)
plt.savefig('../Pedestal/TMM_pedestal.png', dpi = 300)
plt.show()

# %%
import mplhep as hep
plt.style.use(hep.style.ATLAS)
plt.figure(figsize=(8,6), dpi = 100)
plt.bar(TMM_1st['arr_3'][0], TMM_1st['arr_0'][0], label = 'TMM_1st', width = 0.5, align = 'center', alpha = 0.8)
plt.scatter(TMM_1st['arr_3'][0],TMM_1st['arr_0'][0], color = 'k', marker = '.', alpha = 0.5, s = 40)

plt.title('Pedestal')
plt.xlabel('Strip ID')
plt.ylabel('Entries')
plt.xlim(-10, 370)
# plt.ylim(-0.05,1)
plt.legend()
plt.tight_layout()
plt.savefig('../Pedestal/TMM_pedestal_1st.pdf', dpi = 300)
plt.savefig('../Pedestal/TMM_pedestal_1st.png', dpi = 300)
plt.show()

# %%
import mplhep as hep
plt.style.use(hep.style.ATLAS)
plt.figure(figsize=(8,6), dpi = 100)
plt.bar(ExMe['arr_3'][0], ExMe['arr_0'][0], label = 'ExMe', width = 0.5, align = 'center', alpha = 0.6)
plt.scatter(ExMe['arr_3'][0],ExMe['arr_0'][0], color = 'k', marker = '.', alpha = 0.5, s = 40)

plt.title('Pedestal')
plt.xlabel('Strip ID')
plt.ylabel('Entries')
plt.xlim(-10, 1034)
# plt.ylim(2500,3500)
plt.legend()
plt.tight_layout()
plt.savefig('../Pedestal/ExMe_pedestal.pdf', dpi = 300)
plt.savefig('../Pedestal/ExMe_pedestal.png', dpi = 300)
plt.show()

# %%
import mplhep as hep
plt.style.use(hep.style.ATLAS)
plt.figure(figsize=(8,6), dpi = 100)
plt.bar(ExMe['arr_3'][0], ExMe['arr_2'][0], label = 'ExMe', width = 0.5, align = 'center', alpha = 0.6)
plt.scatter(ExMe['arr_3'][0],ExMe['arr_2'][0], color = 'k', marker = '.', alpha = 0.5, s = 40)

plt.title('Pedestal Std')
plt.xlabel('Strip ID')
plt.ylabel('Std [ADC Counts]')
plt.xlim(-10, 1034)
# plt.ylim(2500,3500)
plt.legend()
plt.tight_layout()
plt.savefig('../Pedestal/ExMe_pedestal_std.pdf', dpi = 300)
plt.savefig('../Pedestal/ExMe_pedestal_std.png', dpi = 300)
plt.show()

# %%
import mplhep as hep
plt.style.use(hep.style.ATLAS)
plt.figure(figsize=(8,6), dpi = 100)
plt.bar(TMM['arr_3'][0], TMM['arr_2'][0], label = 'TMM', width = 0.5, align = 'center', alpha = 0.6)
plt.scatter(TMM['arr_3'][0],TMM['arr_2'][0], color = 'k', marker = '.', alpha = 0.5, s = 40)

plt.title('Pedestal Std')
plt.xlabel('Strip ID')
plt.ylabel('Std [ADC Counts]')
plt.xlim(-10, 370)
# plt.ylim(2500,3500)
plt.legend()
plt.tight_layout()
plt.savefig('../Pedestal/TMM_pedestal_std.pdf', dpi = 300)
plt.savefig('../Pedestal/TMM_pedestal_std.png', dpi = 300)
plt.show()

# %%
import mplhep as hep
plt.style.use(hep.style.ATLAS)
plt.figure(figsize=(8,6), dpi = 100)
plt.bar(TMM_1st['arr_3'][0], TMM_1st['arr_2'][0], label = 'TMM_1st', width = 0.5, align = 'center', alpha = 0.6)
plt.scatter(TMM_1st['arr_3'][0],TMM_1st['arr_2'][0], color = 'k', marker = '.', alpha = 0.5, s = 40)

plt.title('Pedestal Std')
plt.xlabel('Strip ID')
plt.ylabel('Std [ADC Counts]')
plt.xlim(-10, 370)
# plt.ylim(2500,3500)
plt.legend()
plt.tight_layout()
plt.savefig('../Pedestal/TMM_pedestal_std_1st.pdf', dpi = 300)
plt.savefig('../Pedestal/TMM_pedestal_std_1st.png', dpi = 300)
plt.show()
